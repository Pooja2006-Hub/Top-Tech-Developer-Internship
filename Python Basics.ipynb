# %%
a = "hi"

# %%
print(a)
# Out:
# hi

# %%
b = "Welcome all"

# %%
print(b)
# Out:
# Welcome all

# %%
a = 1

# %%
print(a)
# Out:
# 1

# %%
name, age = "Pooja", 20

# %%
print(name)
print(age)
# Out:
# Pooja
# 20

# %%
print(name,age)
# Out:
# Pooja 20

# %%
x,y = 1,3

# %%
print(x,y)
# Out:
# 1 3

# %%
name = "Pooja"
age = 20

# %%
print(name,age)
# Out:
# Pooja 20

# %%
a = [1,2,3,3]

# %%
print(a)
# Out:
# [1, 2, 3, 3]

# %%
b = (1,2,2,3)

# %%
print(b)
# Out:
# (1, 2, 2, 3)

# %%
c = {1, 2, 5, 5}

# %%
print(c)
# Out:
# {1, 2, 5}

# %%
d = {"Name" : "Pooja", "Age" : 20}

# %%
print(d)
# Out:
# {'Name': 'Pooja', 'Age': 20}
