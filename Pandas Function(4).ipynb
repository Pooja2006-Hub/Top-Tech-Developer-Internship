# %%
import pandas as pd
df = pd.read_excel('/content/Datasets_Finance.xlsx')

# %%
df
# Out:
#    Applicant ID  Applicant Age Graduate/Non-Graduate Employed/Unemployed  \
# 0          A101             28              Graduate            Employed
# 1          A102             35          Non-Graduate          Unemployed
# 2          A103             42              Graduate            Employed
# 3          A104             50          Non-Graduate       Self Employed
# 4          A105             29              Graduate            Employed
# 5          A106             41              Graduate       Self Employed
# 6          A107             35              Graduate            Employed
# 7          A108             48          Non-Graduate          Unemployed
# 8          A109             30              Graduate            Employed
# 9          A110             46          Non-Graduate       Self Employed
# 10         A111             33              Graduate            Employed
# 11         A112             44          Non-Graduate          Unemployed
# ...

# %%
print(df.head())
# Out:
#   Applicant ID  Applicant Age Graduate/Non-Graduate Employed/Unemployed  \
# 0         A101             28              Graduate            Employed
# 1         A102             35          Non-Graduate          Unemployed
# 2         A103             42              Graduate            Employed
# 3         A104             50          Non-Graduate       Self Employed
# 4         A105             29              Graduate            Employed
#
#    Salary  Loan Amount  Cibil Score Loan Duration Paying Bills Existing Loan  \
# 0   50000       150000          780     12 Months          Yes            No
# 1   18000       300000          580     36 Months           No           Yes
# 2   62000       200000          750     18 Months          Yes            No
# 3   22000       350000          540     48 Motnhs           No           Yes
# 4   70000       120000          810     12 Months          Yes            No
#
#   Co - Applicant ID  Co - Applicant Age  Co - Applicant Salary  \
# ...

# %%
print(df.tail())
# Out:
#    Applicant ID  Applicant Age Graduate/Non-Graduate Employed/Unemployed  \
# 15         A116             43              Graduate       Self Employed
# 16         A117             29              Graduate            Employed
# 17         A118             49          Non-Graduate          Unemployed
# 18         A119             34              Graduate            Employed
# 19         A120             47          Non-Graduate       Self Employed
#
#     Salary  Loan Amount  Cibil Score Loan Duration Paying Bills Existing Loan  \
# 15   25000       270000          600     30 Months           No           Yes
# 16   61000       180000          785     20 Months          Yes            No
# 17   23000       330000          545     38 Months           No           Yes
# 18  770000       110000          820     12 Months          Yes            No
# 19   22000       295000          565     36 Months           No           Yes
#
# ...

# %%
print(df.shape)
# Out:
# (20, 14)

# %%
print(df.columns)
# Out:
# Index(['Applicant ID', 'Applicant Age', 'Graduate/Non-Graduate',
#        'Employed/Unemployed', 'Salary', 'Loan Amount', 'Cibil Score',
#        'Loan Duration', 'Paying Bills', 'Existing Loan', 'Co - Applicant ID',
#        'Co - Applicant Age', 'Co - Applicant Salary',
#        'Loan Approved / Rejected'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Applicant ID              20 non-null     object
#  1   Applicant Age             20 non-null     int64
#  2   Graduate/Non-Graduate     20 non-null     object
#  3   Employed/Unemployed       20 non-null     object
#  4   Salary                    20 non-null     int64
#  5   Loan Amount               20 non-null     int64
#  6   Cibil Score               20 non-null     int64
#  7   Loan Duration             20 non-null     object
#  8   Paying Bills              20 non-null     object
#  9   Existing Loan             20 non-null     object
#  10  Co - Applicant ID         20 non-null     object
#  11  Co - Applicant Age        20 non-null     int64
#  12  Co - Applicant Salary     20 non-null     int64
#  13  Loan Approved / Rejected  20 non-null     object
# ...

# %%
print(df.describe())
# Out:
#        Applicant Age         Salary    Loan Amount  Cibil Score  \
# count       20.00000      20.000000      20.000000    20.000000
# mean        38.65000   78400.000000  227250.000000   676.250000
# std          8.39345  164253.783102   88100.943898   118.564606
# min         27.00000   18000.000000  100000.000000   530.000000
# 25%         30.75000   22000.000000  147500.000000   563.750000
# 50%         38.00000   38000.000000  235000.000000   675.000000
# 75%         46.25000   62750.000000  302500.000000   786.250000
# max         52.00000  770000.000000  350000.000000   830.000000
#
#        Co - Applicant Age  Co - Applicant Salary
# count           20.000000              20.000000
# mean            34.800000           19500.000000
# std              7.302487            9042.298264
# min             25.000000            8000.000000
# 25%             28.000000           10375.000000
# 50%             34.000000           21000.000000
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1311/3437826779.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined
