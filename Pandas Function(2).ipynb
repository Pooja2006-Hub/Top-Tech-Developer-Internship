# %%
import pandas as pd

data = {
    "Name": ["Pooja", "Karishma"],
    "Age": [20, 21],
    "Marks": [85, 90]
}

df = pd.DataFrame(data)

print(df)
# Out:
#        Name  Age  Marks
# 0     Pooja   20     85
# 1  Karishma   21     90

# %%
import pandas as pd

a = [10, 20, 30, 40]

s = pd.Series(a)

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

a = [[10, 20, 30, 40]]

df = pd.DataFrame(a)

print(df.shape)
# Out:
# (1, 4)

# %%
data = {
    "Name": ["Pooja", "Karishma"],
    "Age": [20, 21],
    "Marks": [85, 90]
}

df = pd.DataFrame(data)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
import pandas as pd

data = {
    'Name': ['John', 'Anna', 'Mike', 'Sara', 'John'],
    'Age': [23, 25, 22, 24, 23],
    'Marks': [85, 90, 78, 88, 85]
}

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1871/3810112079.py in <cell line: 0>()
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined
