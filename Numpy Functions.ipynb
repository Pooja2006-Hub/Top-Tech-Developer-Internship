# %%
import numpy as np

a = np.eye(3)
print(a)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
a = np.full((2,3), 7)
print(a)
# Out:
# [[7 7 7]
#  [7 7 7]]

# %%
a = np.full((2,3), 5)

print(a)
b = np.full((3,2), 9)

print(b)
# Out:
# [[5 5 5]
#  [5 5 5]]
# [[9 9]
#  [9 9]
#  [9 9]]

# %%
a = np.random.randint(1, 10, size=(2,3))
print(a)
# Out:
# [[9 6 5]
#  [1 4 2]]

# %%
a = np.random.rand(2,3)
print(a)
# Out:
# [[0.99518464 0.23155322 0.83650591]
#  [0.26345441 0.56935324 0.09589027]]
