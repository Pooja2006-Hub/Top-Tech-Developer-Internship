# %%
import pandas as pd
df = pd.read_excel('/content/loan_approval_dataset.xlsx')

# %%
df
# Out:
#       loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0           1                 2       Graduate             No        9600000
# 1           2                 0   Not Graduate            Yes        4100000
# 2           3                 3       Graduate             No        9100000
# 3           4                 3       Graduate             No        8200000
# 4           5                 5   Not Graduate            Yes        9800000
# ...       ...               ...            ...            ...            ...
# 4264     4265                 5       Graduate            Yes        1000000
# 4265     4266                 0   Not Graduate            Yes        3300000
# 4266     4267                 2   Not Graduate             No        6500000
# 4267     4268                 1   Not Graduate             No        4100000
# 4268     4269                 1       Graduate             No        9200000
#
# ...

# %%
print(df.head())
# Out:
#    loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0        1                 2       Graduate             No        9600000
# 1        2                 0   Not Graduate            Yes        4100000
# 2        3                 3       Graduate             No        9100000
# 3        4                 3       Graduate             No        8200000
# 4        5                 5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
print(df.tail())
# Out:
#       loan_id  no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                 5       Graduate            Yes        1000000
# 4265     4266                 0   Not Graduate            Yes        3300000
# 4266     4267                 2   Not Graduate             No        6500000
# 4267     4268                 1   Not Graduate             No        4100000
# 4268     4269                 1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
# ...

# %%
print(df.shape)
# Out:
# (4269, 13)

# %%
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['loan_id', 'no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
print("\nDataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1   no_of_dependents           4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# ...

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#            loan_id  no_of_dependents   income_annum   loan_amount  \
# count  4269.000000       4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000          2.498712   5.059124e+06  1.513345e+07
# std    1232.498479          1.695910   2.806840e+06  9.043363e+06
# min       1.000000          0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000          1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000          3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000          4.000000   7.500000e+06  2.150000e+07
# max    4269.000000          5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
print("\nAfter Removing Duplicates:")
print(df.drop_duplicates())
# Out:
# After Removing Duplicates:
#       loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0           1                 2       Graduate             No        9600000
# 1           2                 0   Not Graduate            Yes        4100000
# 2           3                 3       Graduate             No        9100000
# 3           4                 3       Graduate             No        8200000
# 4           5                 5   Not Graduate            Yes        9800000
# ...       ...               ...            ...            ...            ...
# 4264     4265                 5       Graduate            Yes        1000000
# 4265     4266                 0   Not Graduate            Yes        3300000
# 4266     4267                 2   Not Graduate             No        6500000
# 4267     4268                 1   Not Graduate             No        4100000
# 4268     4269                 1       Graduate             No        9200000
#
# ...

# %%
print(df.sort_values(by='loan_id'))
# Out:
#       loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0           1                 2       Graduate             No        9600000
# 1           2                 0   Not Graduate            Yes        4100000
# 2           3                 3       Graduate             No        9100000
# 3           4                 3       Graduate             No        8200000
# 4           5                 5   Not Graduate            Yes        9800000
# ...       ...               ...            ...            ...            ...
# 4264     4265                 5       Graduate            Yes        1000000
# 4265     4266                 0   Not Graduate            Yes        3300000
# 4266     4267                 2   Not Graduate             No        6500000
# 4267     4268                 1   Not Graduate             No        4100000
# 4268     4269                 1       Graduate             No        9200000
#
# ...

# %%
print(df.isnull())
# Out:
#       loan_id  no_of_dependents   education   self_employed   income_annum  \
# 0       False             False       False           False          False
# 1       False             False       False           False          False
# 2       False             False       False           False          False
# 3       False             False       False           False          False
# 4       False             False       False           False          False
# ...       ...               ...         ...             ...            ...
# 4264    False             False       False           False          False
# 4265    False             False       False           False          False
# 4266    False             False       False           False          False
# 4267    False             False       False           False          False
# 4268    False             False       False           False          False
#
# ...

# %%
print(df.notnull())
# Out:
#       loan_id  no_of_dependents   education   self_employed   income_annum  \
# 0        True              True        True            True           True
# 1        True              True        True            True           True
# 2        True              True        True            True           True
# 3        True              True        True            True           True
# 4        True              True        True            True           True
# ...       ...               ...         ...             ...            ...
# 4264     True              True        True            True           True
# 4265     True              True        True            True           True
# 4266     True              True        True            True           True
# 4267     True              True        True            True           True
# 4268     True              True        True            True           True
#
# ...

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4264    False
# 4265    False
# 4266    False
# 4267    False
# 4268    False
# Length: 4269, dtype: bool

# %%
print(df.sample())
# Out:
#      loan_id  no_of_dependents      education  self_employed   income_annum  \
# 875      876                 1   Not Graduate            Yes        1700000
#
#       loan_amount   loan_term   cibil_score   residential_assets_value  \
# 875       4500000          20           480                     200000
#
#       commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 875                    600000               5400000            1900000
#
#      loan_status
# 875     Rejected

# %%
print(df.rename(columns={"cibil_score":"Credit Score"}))
# Out:
#       loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0           1                 2       Graduate             No        9600000
# 1           2                 0   Not Graduate            Yes        4100000
# 2           3                 3       Graduate             No        9100000
# 3           4                 3       Graduate             No        8200000
# 4           5                 5   Not Graduate            Yes        9800000
# ...       ...               ...            ...            ...            ...
# 4264     4265                 5       Graduate            Yes        1000000
# 4265     4266                 0   Not Graduate            Yes        3300000
# 4266     4267                 2   Not Graduate             No        6500000
# 4267     4268                 1   Not Graduate             No        4100000
# 4268     4269                 1       Graduate             No        9200000
#
# ...

# %%
print(df["loan_id"].mean())
# Out:
# 2135.0

# %%
print(df["loan_id"].median())
# Out:
# 2135.0

# %%
print(df["loan_id"].var())
# Out:
# 1519052.5

# %%
print(df["loan_id"].min())
# Out:
# 1

# %%
print(df["loan_id"].max())
# Out:
# 4269

# %%
print(df["loan_id"].sum())
# Out:
# 9114315

# %%
print(df["loan_id"].count())
# Out:
# 4269

# %%
print(df.groupby("loan_id").sum())
# Out:
#          no_of_dependents      education  self_employed   income_annum  \
# loan_id
# 1                       2       Graduate             No        9600000
# 2                       0   Not Graduate            Yes        4100000
# 3                       3       Graduate             No        9100000
# 4                       3       Graduate             No        8200000
# 5                       5   Not Graduate            Yes        9800000
# ...                   ...            ...            ...            ...
# 4265                    5       Graduate            Yes        1000000
# 4266                    0   Not Graduate            Yes        3300000
# 4267                    2   Not Graduate             No        6500000
# 4268                    1   Not Graduate             No        4100000
# 4269                    1       Graduate             No        9200000
#
#           loan_amount   loan_term   cibil_score   residential_assets_value  \
# loan_id
# ...

# %%
df.loc[len(df)] = [4270, 2, "Graduate", "No", 850000, 2500000, 15, 782, 4200000, 1500000, 900000, 600000, "Approved"]
print(df)
# Out:
#       loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0           1                 2       Graduate             No        9600000
# 1           2                 0   Not Graduate            Yes        4100000
# 2           3                 3       Graduate             No        9100000
# 3           4                 3       Graduate             No        8200000
# 4           5                 5   Not Graduate            Yes        9800000
# ...       ...               ...            ...            ...            ...
# 4265     4266                 0   Not Graduate            Yes        3300000
# 4266     4267                 2   Not Graduate             No        6500000
# 4267     4268                 1   Not Graduate             No        4100000
# 4268     4269                 1       Graduate             No        9200000
# 4269     4270                 2       Graduate             No         850000
#
# ...

# %%
df = df.drop("no_of_dependents", axis = 1)
print(df)
# Out:
#       loan_id      education  self_employed   income_annum   loan_amount  \
# 0           1       Graduate             No        9600000      29900000
# 1           2   Not Graduate            Yes        4100000      12200000
# 2           3       Graduate             No        9100000      29700000
# 3           4       Graduate             No        8200000      30700000
# 4           5   Not Graduate            Yes        9800000      24200000
# ...       ...            ...            ...            ...           ...
# 4265     4266   Not Graduate            Yes        3300000      11300000
# 4266     4267   Not Graduate             No        6500000      23900000
# 4267     4268   Not Graduate             No        4100000      12800000
# 4268     4269       Graduate             No        9200000      29700000
# 4269     4270       Graduate             No         850000       2500000
#
#        loan_term   cibil_score   residential_assets_value  \
# ...

# %%
new = df.copy()
print(new)
# Out:
#       loan_id      education  self_employed   income_annum   loan_amount  \
# 0           1       Graduate             No        9600000      29900000
# 1           2   Not Graduate            Yes        4100000      12200000
# 2           3       Graduate             No        9100000      29700000
# 3           4       Graduate             No        8200000      30700000
# 4           5   Not Graduate            Yes        9800000      24200000
# ...       ...            ...            ...            ...           ...
# 4265     4266   Not Graduate            Yes        3300000      11300000
# 4266     4267   Not Graduate             No        6500000      23900000
# 4267     4268   Not Graduate             No        4100000      12800000
# 4268     4269       Graduate             No        9200000      29700000
# 4269     4270       Graduate             No         850000       2500000
#
#        loan_term   cibil_score   residential_assets_value  \
# ...

# %%
df = df.drop(df.index[-1])
print(df)
# Out:
#       loan_id      education  self_employed   income_annum   loan_amount  \
# 0           1       Graduate             No        9600000      29900000
# 1           2   Not Graduate            Yes        4100000      12200000
# 2           3       Graduate             No        9100000      29700000
# 3           4       Graduate             No        8200000      30700000
# 4           5   Not Graduate            Yes        9800000      24200000
# ...       ...            ...            ...            ...           ...
# 4264     4265       Graduate            Yes        1000000       2300000
# 4265     4266   Not Graduate            Yes        3300000      11300000
# 4266     4267   Not Graduate             No        6500000      23900000
# 4267     4268   Not Graduate             No        4100000      12800000
# 4268     4269       Graduate             No        9200000      29700000
#
#        loan_term   cibil_score   residential_assets_value  \
# ...

# %%
df = df.replace(559,450)
print(df)
# Out:
#       loan_id      education  self_employed   income_annum   loan_amount  \
# 0           1       Graduate             No        9600000      29900000
# 1           2   Not Graduate            Yes        4100000      12200000
# 2           3       Graduate             No        9100000      29700000
# 3           4       Graduate             No        8200000      30700000
# 4           5   Not Graduate            Yes        9800000      24200000
# ...       ...            ...            ...            ...           ...
# 4264     4265       Graduate            Yes        1000000       2300000
# 4265     4266   Not Graduate            Yes        3300000      11300000
# 4266     4267   Not Graduate             No        6500000      23900000
# 4267     4268   Not Graduate             No        4100000      12800000
# 4268     4269       Graduate             No        9200000      29700000
#
#        loan_term   cibil_score   residential_assets_value  \
# ...

# %%
df
# Out:
#       loan_id      education  self_employed   income_annum   loan_amount  \
# 0           1       Graduate             No        9600000      29900000
# 1           2   Not Graduate            Yes        4100000      12200000
# 2           3       Graduate             No        9100000      29700000
# 3           4       Graduate             No        8200000      30700000
# 4           5   Not Graduate            Yes        9800000      24200000
# ...       ...            ...            ...            ...           ...
# 4264     4265       Graduate            Yes        1000000       2300000
# 4265     4266   Not Graduate            Yes        3300000      11300000
# 4266     4267   Not Graduate             No        6500000      23900000
# 4267     4268   Not Graduate             No        4100000      12800000
# 4268     4269       Graduate             No        9200000      29700000
#
#        loan_term   cibil_score   residential_assets_value  \
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df["education"] = df["education"].str.upper()
print(df)
# Out:
#       loan_id      education self_employed  income_annum  loan_amount  \
# 0           1       GRADUATE            No       9600000     29900000
# 1           2   NOT GRADUATE           Yes       4100000     12200000
# 2           3       GRADUATE            No       9100000     29700000
# 3           4       GRADUATE            No       8200000     30700000
# 4           5   NOT GRADUATE           Yes       9800000     24200000
# ...       ...            ...           ...           ...          ...
# 4264     4265       GRADUATE           Yes       1000000      2300000
# 4265     4266   NOT GRADUATE           Yes       3300000     11300000
# 4266     4267   NOT GRADUATE            No       6500000     23900000
# 4267     4268   NOT GRADUATE            No       4100000     12800000
# 4268     4269       GRADUATE            No       9200000     29700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0            12          778                   2400000
# ...

# %%
df["education"] = df["education"].str.lower()
print(df)
# Out:
#       loan_id      education self_employed  income_annum  loan_amount  \
# 0           1       graduate            No       9600000     29900000
# 1           2   not graduate           Yes       4100000     12200000
# 2           3       graduate            No       9100000     29700000
# 3           4       graduate            No       8200000     30700000
# 4           5   not graduate           Yes       9800000     24200000
# ...       ...            ...           ...           ...          ...
# 4264     4265       graduate           Yes       1000000      2300000
# 4265     4266   not graduate           Yes       3300000     11300000
# 4266     4267   not graduate            No       6500000     23900000
# 4267     4268   not graduate            No       4100000     12800000
# 4268     4269       graduate            No       9200000     29700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0            12          778                   2400000
# ...

# %%
df.query('cibil_score > 800')
# Out:
#       loan_id      education self_employed  income_annum  loan_amount  \
# 29         30   not graduate           Yes       9000000     31500000
# 33         34   not graduate           Yes       8400000     22000000
# 38         39       graduate            No       3600000      7700000
# 41         42   not graduate            No       9100000     24900000
# 55         56   not graduate            No       6700000     24500000
# ...       ...            ...           ...           ...          ...
# 4247     4248   not graduate            No       3100000      9800000
# 4249     4250       graduate            No       1100000      4000000
# 4253     4254       graduate           Yes       7000000     26200000
# 4261     4262       graduate           Yes       3000000      7500000
# 4263     4264       graduate            No       5000000     12700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 29           10          850                  21800000
# ...

# %%
print(df.dtypes)
# Out:
# loan_id                      int64
# education                   object
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term                    int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_asset_value             int64
# loan_status                 object
# dtype: object
